# %%
import benchmark.utils as bu

# %%
bu.plot_points_vs_x_parallel(trackpy_processed, 12)

# %%
bu.plot_points_vs_x_perpendicular(trackpy_processed, False, 40)

# %%
bu.plot_points_vs_x_perpendicular(trackpy_processed, True, 20)

# %%
bu.plot_points_vs_x_perpendicular_overlapping(trackpy_processed, end_offset=8, colormap='Blues_r', abs=False, bin_length=5)

# %%
bu.plot_points_vs_x_perpendicular_overlapping(trackpy_processed, end_offset=8, colormap='Blues_r', bin_length=5)

# %%
bu.plot_velocities_vs_x_perpendicular(trackpy_processed, False, frame_rel=-1)

# %%
bu.plot_velocities_vs_x_perpendicular(trackpy_processed, frame_rel=-1)

# %%
bu.plot_points_vs_frame(trackpy_processed[trackpy_processed['cut'] == False])

# %%
bu.plot_v_perpendicular_vs_time(trackpy_processed, end_offset=8, output_path='benchmark/plots/piv_v_perpendicular_over_time_abs.png')

# %%
bu.plot_v_perpendicular_vs_time(trackpy_processed, abs=False, end_offset=8)
